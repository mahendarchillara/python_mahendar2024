# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
churndf=pd.read_csv("Churn.csv")
churndf
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
churndf.columns
# Out:
# Index(['year', 'customer_id', 'phone_no', 'gender', 'age',
#        'no_of_days_subscribed', 'multi_screen', 'mail_subscribed',
#        'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#        'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
#        'customer_support_calls', 'churn'],
#       dtype='object')

# %%
cat_columns=churndf.select_dtypes(include='object').columns
num_columns=churndf.select_dtypes(exclude='object').columns

# %%
cat_columns,num_columns
# Out:
# (Index(['phone_no', 'gender', 'multi_screen', 'mail_subscribed'], dtype='object'),
#  Index(['year', 'customer_id', 'age', 'no_of_days_subscribed',
#         'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#         'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
#         'customer_support_calls', 'churn'],
#        dtype='object'))

# %% [markdown]
# **isnull**

# %%
churndf.isnull().sum()
# Out:
# year                       0
# customer_id                0
# phone_no                   0
# gender                    24
# age                        0
# no_of_days_subscribed      0
# multi_screen               0
# mail_subscribed            0
# weekly_mins_watched        0
# minimum_daily_mins         0
# maximum_daily_mins         0
# weekly_max_night_mins      0
# videos_watched             0
# maximum_days_inactive     28
# customer_support_calls     0
# churn                     35
# dtype: int64

# %% [markdown]
# **mode**

# %%
gender_mode=churndf['gender'].mode()
churndf['gender'].fillna(gender_mode[0],inplace=True)

maximum_days_inactive_mode=churndf['maximum_days_inactive'].mode()
churndf['maximum_days_inactive'].fillna(maximum_days_inactive_mode[0],inplace=True)

churn_mode=churndf['churn'].mode()
churndf['churn'].fillna(churn_mode[0],inplace=True)
# Out:
# C:\Users\mahen\AppData\Local\Temp\ipykernel_10316\3376306148.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   churndf['gender'].fillna(gender_mode[0],inplace=True)
# C:\Users\mahen\AppData\Local\Temp\ipykernel_10316\3376306148.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
churndf.isnull().sum()
# Out:
# year                      0
# customer_id               0
# phone_no                  0
# gender                    0
# age                       0
# no_of_days_subscribed     0
# multi_screen              0
# mail_subscribed           0
# weekly_mins_watched       0
# minimum_daily_mins        0
# maximum_daily_mins        0
# weekly_max_night_mins     0
# videos_watched            0
# maximum_days_inactive     0
# customer_support_calls    0
# churn                     0
# dtype: int64

# %%
churndf['maximum_days_inactive'].astype('int')
# Out:
# 0       4
# 1       3
# 2       4
# 3       3
# 4       3
#        ..
# 1995    4
# 1996    3
# 1997    5
# 1998    3
# 1999    3
# Name: maximum_days_inactive, Length: 2000, dtype: int32

# %%
churndf['churn'].astype('int')
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    1
# Name: churn, Length: 2000, dtype: int32

# %%
churndf.dtypes
# Out:
# year                        int64
# customer_id                 int64
# phone_no                   object
# gender                     object
# age                         int64
# no_of_days_subscribed       int64
# multi_screen               object
# mail_subscribed            object
# weekly_mins_watched       float64
# minimum_daily_mins        float64
# maximum_daily_mins        float64
# weekly_max_night_mins       int64
# videos_watched              int64
# maximum_days_inactive     float64
# customer_support_calls      int64
# churn                     float64
# dtype: object

# %% [markdown]
# **Categorical_data_analysis**

# %% [markdown]
# **unique**

# %%
#unique

for i in cat_columns[1:]:
    categoric=churndf[i].unique()
    print(f"{i}:{categoric}")
# Out:
# gender:['Female' 'Male']
# multi_screen:['no' 'yes']
# mail_subscribed:['no' 'yes']

# %% [markdown]
# **nunique**

# %%
#nunique

for i in cat_columns[1:]:
    no_of_cat_columns=churndf[i].nunique()
    print(f"The number of categories of  {i}: {no_of_cat_columns}")
# Out:
# The number of categories of  gender: 2
# The number of categories of  multi_screen: 2
# The number of categories of  mail_subscribed: 2

# %% [markdown]
# **value_counts**

# %%
#value_counts
for i in cat_columns[1:]:
    cat_value_counts=churndf[i].value_counts()
    print(cat_value_counts)
# Out:
# gender
# Male      1077
# Female     923
# Name: count, dtype: int64
# multi_screen
# no     1802
# yes     198
# Name: count, dtype: int64
# mail_subscribed
# no     1430
# yes     570
# Name: count, dtype: int64

# %%
import os

try:
    root_dir=os.getcwd()
    new_folder="All_Cat_Columns"
    new_path=os.path.join(root_dir,new_folder)
    os.makedirs(new_path)
except Exception as  e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\mahen\\Batch-8\\data_files\\All_Cat_Columns'

# %%
root_directory=os.getcwd()
new_folder="value_counts_df"
dir=os.path.join(root_directory,new_folder)
os.makedirs(dir)
dir
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[311], line 4
#       2 new_folder="value_counts_df"
#       3 dir=os.path.join(root_directory,new_folder)
# ----> 4 os.makedirs(dir)
#       5 dir
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\mahen\\Batch-8\\data_files\\value_counts_df'

# %%
for i in cat_columns[1:]:
    tdf=churndf[i].value_counts()
    keys=tdf.keys()
    values=tdf.values
    cols=[f"{i}","Counts"]
    tele_churn_df=pd.DataFrame(zip(keys,values),columns=cols)
    tele_churn_df.to_csv(f"{dir}\\{i}",index=False)

# %%
dfs=os.listdir(dir)
dfs
# Out:
# ['gender', 'mail_subscribed', 'multi_screen']

# %% [markdown]
# **BarChart**

# %%
pd.read_csv(f"{dir}\\gender")
# Out:
#    gender  Counts
# 0    Male    1077
# 1  Female     923

# %%
pd.read_csv(f"{dir}\\mail_subscribed")
# Out:
#   mail_subscribed  Counts
# 0              no    1430
# 1             yes     570

# %%
pd.read_csv(f"{dir}\\multi_screen")
# Out:
#   multi_screen  Counts
# 0           no    1802
# 1          yes     198

# %%
    for i in dfs:
        df=pd.read_csv(f"{dir}\\{i}")
        plt.bar(f"{i}",
                "Counts",
                data=df)
        plt.title(f"{i}")
        plt.show()

# %% [markdown]
# **countplot**

# %%
cat_columns
# Out:
# Index(['phone_no', 'gender', 'multi_screen', 'mail_subscribed'], dtype='object')

# %%
#gender_multiscreen

gender_multiscreen=pd.crosstab(churndf['gender'],churndf['multi_screen'])
gender_multiscreen
# Out:
# multi_screen   no  yes
# gender
# Female        835   88
# Male          967  110

# %%
#gender_mailsubscribed

gender_mailsubscribed=pd.crosstab(churndf['gender'],churndf['mail_subscribed'])
gender_mailsubscribed
# Out:
# mail_subscribed   no  yes
# gender
# Female           639  284
# Male             791  286

# %%
plt.figure(figsize=(14,3))
gender_multiscreen.plot(kind='bar')
plt.title('gender_multiscreen')
plt.show()
gender_mailsubscribed.plot(kind='bar')
plt.title('gender_mailsubscribed')
plt.show()

# %% [markdown]
# **Pie-chart**

# %%
for i in cat_columns[1:]:
    keys=churndf[i].value_counts().keys()
    values=churndf[i].value_counts().values
    plt.subplot(1,2,1).pie(values,
           labels=keys,
           autopct="%0.2f%%",
           startangle=180)
    plt.title("pi_chart")
    plt.show()

# %% [markdown]
# **Numerical_data_Analysis**

# %%
num_columns
# Out:
# Index(['year', 'customer_id', 'age', 'no_of_days_subscribed',
#        'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#        'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
#        'customer_support_calls', 'churn'],
#       dtype='object')

# %%
num_df=churndf.describe()
num_df
# Out:
#          year    customer_id         age  no_of_days_subscribed  \
# count  2000.0    2000.000000  2000.00000            2000.000000
# mean   2015.0  554887.157500    38.69050              99.750000
# std       0.0  261033.690318    10.20641              39.755386
# min    2015.0  100198.000000    18.00000               1.000000
# 25%    2015.0  328634.750000    32.00000              73.000000
# 50%    2015.0  567957.500000    37.00000              99.000000
# 75%    2015.0  773280.250000    44.00000             127.000000
# max    2015.0  999961.000000    82.00000             243.000000
#
#        weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# count          2000.000000         2000.000000         2000.000000
# mean            270.178425           10.198700           30.620780
# std              80.551627            2.785519            9.129165
# min               0.000000            0.000000            0.000000
# ...

# %%
num_df.drop(['year','customer_id','churn'],axis=1,inplace=True)

# %%
num_df
# Out:
#               age  no_of_days_subscribed  weekly_mins_watched  \
# count  2000.00000            2000.000000          2000.000000
# mean     38.69050              99.750000           270.178425
# std      10.20641              39.755386            80.551627
# min      18.00000               1.000000             0.000000
# 25%      32.00000              73.000000           218.212500
# 50%      37.00000              99.000000           269.925000
# 75%      44.00000             127.000000           324.675000
# max      82.00000             243.000000           526.200000
#
#        minimum_daily_mins  maximum_daily_mins  weekly_max_night_mins  \
# count         2000.000000         2000.000000            2000.000000
# mean            10.198700           30.620780             100.415500
# std              2.785519            9.129165              19.529454
# min              0.000000            0.000000              42.000000
# ...

# %% [markdown]
# **Histogram**

# %%
for i in num_columns[2:11]:
    data=churndf[i]
    sns.histplot(churndf[i],bins=10,kde=False)
    plt.xlabel(i)
    plt.ylabel("Frequency")
    plt.show()

# %% [markdown]
# **Boxplot_creation**

# %%
for i in num_columns[2:11]:
    data2=churndf[i]
    sns.boxplot(x=data2)
    plt.title(f"{i}")
    plt.show()

# %% [markdown]
# **Outlier_Analysis**

# %%
#non_outlier

age_data=churndf["age"]
q1=np.percentile(churndf["age"],25)
q2=np.percentile(churndf["age"],50)
q3=np.percentile(churndf["age"],75)
IQR=q3-q1
lb=q1-1.5*IQR
ub=q3+1.5*IQR

print(lb,ub)

con1=age_data>lb
con2=age_data<ub
con3=con1&con2
non_outlier_df=churndf[con3]

non_outlier_df[["age"]]
# Out:
# 14.0 62.0
#       age
# 0      36
# 1      39
# 3      24
# 4      40
# 5      31
# ...   ...
# 1995   54
# 1996   45
# 1997   53
# 1998   40
# 1999   37
#
# [1926 rows x 1 columns]

# %%
#outlier

# %%
age_data=churndf["age"]
q1=np.percentile(churndf["age"],25)
q2=np.percentile(churndf["age"],50)
q3=np.percentile(churndf["age"],75)
IQR=q3-q1
lb=q1-1.5*IQR
ub=q3+1.5*IQR
con1=age_data<lb
con2=age_data>ub
con4=con1|con2

outlier_df=churndf[con4]

outlier_df[["age"]]
# Out:
#       age
# 2      65
# 30     63
# 71     67
# 87     64
# 154    66
# ...   ...
# 1852   65
# 1855   72
# 1884   69
# 1970   67
# 1981   70
#
# [63 rows x 1 columns]

# %%
import os
try:
    root_dir=os.getcwd()
    new_folder_n="non_outlier_df"
    new_path_n=os.path.join(root_dir,new_folder_n)
    os.makedirs(new_path_n)
except Exception as e:
    print(e)

# %%
for i in num_columns[2:11]:
    all_data=churndf[i]
    q1=np.percentile(churndf[i],25)
    q2=np.percentile(churndf[i],50)
    q3=np.percentile(churndf[i],75)
    IQR=q3-q1
    lb=q1-1.5*IQR
    ub=q3+1.5*IQR
    con1=all_data>lb
    con2=all_data<ub
    con3=con1&con2
    non_outlier_all_data=churndf[con3]
    non_outlier_all_data.to_csv(f"{new_path_n}\\{i}.csv",index=False)
non_outlier_all_data[[i]]
# Out:
#       customer_support_calls
# 0                          1
# 1                          2
# 3                          3
# 4                          1
# 6                          0
# ...                      ...
# 1995                       2
# 1996                       1
# 1997                       0
# 1998                       3
# 1999                       1
#
# [1839 rows x 1 columns]

# %%
import os
try:
    root_directory=os.getcwd()
    new_folder_n2="Outlier_df"
    new_path_n2=os.path.join(root_directory,new_folder_n2)
    os.makedirs(new_path_n2)
except  Exception as e:
    print(e)

# %%
for i in num_columns[2:11]:
    all_data2=churndf[i]
    q1=np.percentile(churndf[i],25)
    q2=np.percentile(churndf[i],50)
    q3=np.percentile(churndf[i],75)
    IQR=q3-q1
    lb=q1-1.5*IQR
    ub=q3+1.5*IQR
    con1=all_data2<lb
    con2=all_data2>ub
    con3=con1|con2
    outlier_data_n=churndf[con3]
    outlier_data_n.to_csv(f"{new_path_n2}\\{i}.csv",index=False)
outlier_data_n[[i]]
# Out:
#       customer_support_calls
# 2                          5
# 5                          4
# 7                          5
# 10                         4
# 24                         4
# ...                      ...
# 1884                       6
# 1887                       4
# 1926                       5
# 1931                       4
# 1933                       4
#
# [161 rows x 1 columns]

# %% [markdown]
# **Transformations Methods**

# %%
from sklearn.preprocessing import power_transform
pt=power_transform(churndf[["age"]])

transform_age=pt
print(transform_age)

plt.figure(figsize=(14,3))
#before
plt.subplot(1,2,1).hist(churndf["age"],bins=10)
#after
plt.subplot(1,2,2).hist(transform_age,bins=10)
plt.show()
# Out:
# [[-0.12838596]
#  [ 0.18786111]
#  [ 2.07754042]
#  ...
#  [ 1.34882454]
#  [ 0.28673627]
#  [-0.0195074 ]]

# %% [markdown]
# **encoding_methods**

# %%
#1 MAP

# %%
churn_data=pd.read_csv("Churn.csv")

churn_data["gender"].replace("nan",np.nan,inplace=True)
mode_gender=churn_data["gender"].mode()
churn_data["gender"].fillna(mode_gender[0],inplace=True)

mode_maximum_days_inactive=churn_data["maximum_days_inactive"].mode()
churn_data["maximum_days_inactive"].fillna(mode_maximum_days_inactive[0],inplace=True)

mode_churn=churn_data["churn"].mode()
churn_data["churn"].fillna(mode_churn[0],inplace=True)

churn_data["maximum_days_inactive"].astype('int')
churn_data["churn"].astype('int')
# Out:
# C:\Users\mahen\AppData\Local\Temp\ipykernel_10316\2893210222.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   churn_data["gender"].replace("nan",np.nan,inplace=True)
# C:\Users\mahen\AppData\Local\Temp\ipykernel_10316\2893210222.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
for i in cat_columns:
    unique_labels=sorted(churn_data[i].unique())
    list1=[i for i in range(len(unique_labels))]
    dict1=dict(zip(unique_labels,list1))
    dict1
    churn_data[i]=churn_data[i].map(dict1)
churn_data
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198      1754       0   36                     62
# 1     2015       100643       299       0   39                    149
# 2     2015       100756       957       0   65                    126
# 3     2015       101595        75       0   24                    131
# 4     2015       101653       517       0   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132      1224       0   54                     75
# 1996  2015       998086      1188       1   45                    127
# 1997  2015       998474       553       1   53                     94
# 1998  2015       998934       706       1   40                     94
# 1999  2015       999961      1834       1   37                     73
#
#       multi_screen  mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %% [markdown]
# #np.where

# %%
churn_data=pd.read_csv("Churn.csv")

churn_data["gender"].replace("nan",np.nan,inplace=True)
mode_gender=churn_data["gender"].mode()
churn_data["gender"].fillna(mode_gender[0],inplace=True)

churn_data["maximum_days_inactive"].replace("nan",np.nan,inplace=True)
mode_maximum_days_inactive=churn_data["maximum_days_inactive"].mode()
churn_data["maximum_days_inactive"].fillna(mode_maximum_days_inactive[0],inplace=True)

churn_data["churn"].replace("nan",np.nan,inplace=True)
mode_churn=churn_data["churn"].mode()
churn_data["churn"].fillna(mode_churn[0],inplace=True)
# Out:
# C:\Users\mahen\AppData\Local\Temp\ipykernel_10316\1128105701.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   churn_data["gender"].replace("nan",np.nan,inplace=True)
# C:\Users\mahen\AppData\Local\Temp\ipykernel_10316\1128105701.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
churn_data['maximum_days_inactive'].astype('int')
churn_data['churn'].astype('int')
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    1
# Name: churn, Length: 2000, dtype: int32

# %%
con1=churn_data["gender"]=="Male"
churn_data["gender"]=np.where(con1,0,1)
churn_data

con2=churn_data["multi_screen"]=="yes"
churn_data["multi_screen"]=np.where(con2,0,1)

con3=churn_data["mail_subscribed"]=="yes"
churn_data["mail_subscribed"]=np.where(con3,0,1)

churn_data
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743       1   36                     62
# 1     2015       100643  340-5930       1   39                    149
# 2     2015       100756  372-3750       1   65                    126
# 3     2015       101595  331-4902       1   24                    131
# 4     2015       101653  351-8398       1   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387       1   54                     75
# 1996  2015       998086  383-9255       1   45                    127
# 1997  2015       998474  353-2080       1   53                     94
# 1998  2015       998934  359-7788       1   40                     94
# 1999  2015       999961  414-1496       1   37                     73
#
#       multi_screen  mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %% [markdown]
# #3LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
churn_data=pd.read_csv("Churn.csv")

churn_data["gender"].replace("nan",np.nan,inplace=True)
mode_gender=churn_data["gender"].mode()
churn_data["gender"].fillna(mode_gender[0],inplace=True)

churn_data["maximum_days_inactive"].replace("nan",np.nan,inplace=True)
mode_maximum_days_inactive=churn_data["maximum_days_inactive"].mode()
churn_data["maximum_days_inactive"].fillna(mode_maximum_days_inactive[0],inplace=True)

churn_data["churn"].replace("nan",np.nan,inplace=True)
mode_churn=churn_data["churn"].mode()
churn_data["churn"].fillna(mode_churn[0],inplace=True)

churn_data["maximum_days_inactive"].astype('int')
churn_data['churn'].astype('int')

le=LabelEncoder()
for i in cat_columns:
    churn_data[i]=le.fit_transform(churn_data[i])
churn_data
# Out:
# C:\Users\mahen\AppData\Local\Temp\ipykernel_10316\4127991457.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   churn_data["gender"].replace("nan",np.nan,inplace=True)
# C:\Users\mahen\AppData\Local\Temp\ipykernel_10316\4127991457.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# #Onehot Encoding

# %%
churn_data=pd.read_csv("Churn.csv")

encoded_data=pd.get_dummies(churn_data)
encoded_data
# Out:
#       year  customer_id  age  no_of_days_subscribed  weekly_mins_watched  \
# 0     2015       100198   36                     62               148.35
# 1     2015       100643   39                    149               294.45
# 2     2015       100756   65                    126                87.30
# 3     2015       101595   24                    131               321.30
# 4     2015       101653   40                    191               243.00
# ...    ...          ...  ...                    ...                  ...
# 1995  2015       997132   54                     75               182.25
# 1996  2015       998086   45                    127               273.45
# 1997  2015       998474   53                     94               128.85
# 1998  2015       998934   40                     94               178.05
# 1999  2015       999961   37                     73               326.70
#
#       minimum_daily_mins  maximum_daily_mins  weekly_max_night_mins  \
# ...

# %% [markdown]
# #Scaling_Methods

# %%
#standardScaler

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
encoded_data["ss_age_data"]=ss.fit_transform(encoded_data[["age"]])
encoded_data
# Out:
#       year  customer_id  age  no_of_days_subscribed  weekly_mins_watched  \
# 0     2015       100198   36                     62               148.35
# 1     2015       100643   39                    149               294.45
# 2     2015       100756   65                    126                87.30
# 3     2015       101595   24                    131               321.30
# 4     2015       101653   40                    191               243.00
# ...    ...          ...  ...                    ...                  ...
# 1995  2015       997132   54                     75               182.25
# 1996  2015       998086   45                    127               273.45
# 1997  2015       998474   53                     94               128.85
# 1998  2015       998934   40                     94               178.05
# 1999  2015       999961   37                     73               326.70
#
#       minimum_daily_mins  maximum_daily_mins  weekly_max_night_mins  \
# ...

# %%
#min_max_scaler

# %%
from sklearn.preprocessing import minmax_scale
mms=minmax_scale(encoded_data[["age"]])
encoded_data["mms_age_data"]=minmax_scale(encoded_data[["age"]])
encoded_data
# Out:
#       year  customer_id  age  no_of_days_subscribed  weekly_mins_watched  \
# 0     2015       100198   36                     62               148.35
# 1     2015       100643   39                    149               294.45
# 2     2015       100756   65                    126                87.30
# 3     2015       101595   24                    131               321.30
# 4     2015       101653   40                    191               243.00
# ...    ...          ...  ...                    ...                  ...
# 1995  2015       997132   54                     75               182.25
# 1996  2015       998086   45                    127               273.45
# 1997  2015       998474   53                     94               128.85
# 1998  2015       998934   40                     94               178.05
# 1999  2015       999961   37                     73               326.70
#
#       minimum_daily_mins  maximum_daily_mins  weekly_max_night_mins  \
# ...
